# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# %%
# Set up headless browser (optional)
options = Options()
options.headless = True  # Set to False to see the browser window

# %%
# Set your local ChromeDriver path
driver_path = 'C:/WebDrivers/chromedriver.exe'

# %%
# Start the driver
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)

# %%
# Get Data
league_url = "https://fbref.com/en/comps/10/Championship-Stats"
driver.get(league_url)

# %%
# Get the HTML content
data = driver.page_source

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data)
league_table = soup.select_one('table.stats_table') # identify correct table element using its CSS class: stats_table
links = league_table.find_all('a') # find all team links using their anchor tags
links = [l.get("href") for l in links] # get the href attribute value of each anchor element
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links] # change relative links to absolute links

# %%
from io import StringIO

# %%
driver.get(team_urls[0]) # get html data from league leader
data = StringIO(driver.page_source) # wrap HTML content inside a "file-like" object, which pandas can read

# %%
import pandas as pd

# %%
matches = pd.read_html(data, match="Scores & Fixtures")[0]
# Out:
#           Date           Time          Comp                Round  Day  Venue  \
# 0   2024-08-10  12:30 (13:30)  Championship          Matchweek 1  Sat   Home
# 1   2024-08-14  20:00 (21:00)       EFL Cup          First round  Wed   Home
# 2   2024-08-17  12:30 (13:30)  Championship          Matchweek 2  Sat   Away
# 3   2024-08-23  20:00 (21:00)  Championship          Matchweek 3  Fri   Away
# 4   2024-08-31  15:00 (16:00)  Championship          Matchweek 4  Sat   Home
# 5   2024-09-14  12:30 (13:30)  Championship          Matchweek 5  Sat   Home
# 6   2024-09-21  15:00 (16:00)  Championship          Matchweek 6  Sat   Away
# 7   2024-09-28  15:00 (16:00)  Championship          Matchweek 7  Sat   Home
# 8   2024-10-01  19:45 (20:45)  Championship          Matchweek 8  Tue   Away
# 9   2024-10-04  20:00 (21:00)  Championship          Matchweek 9  Fri   Away
# 10  2024-10-18  20:00 (21:00)  Championship         Matchweek 10  Fri   Home
# 11  2024-10-22  19:45 (20:45)  Championship         Matchweek 11  Tue   Home
# 12  2024-10-26  12:30 (13:30)  Championship         Matchweek 12  Sat   Away
# 13  2024-11-02  15:00 (16:00)  Championship         Matchweek 13  Sat   Home
# 14  2024-11-06  19:45 (20:45)  Championship         Matchweek 14  Wed   Away
# 15  2024-11-09  15:00 (16:00)  Championship         Matchweek 15  Sat   Home
# 16  2024-11-24  15:00 (16:00)  Championship         Matchweek 16  Sun   Away
# 17  2024-11-27  19:45 (20:45)  Championship         Matchweek 17  Wed   Home
# 18  2024-11-30  13:30 (14:30)  Championship         Matchweek 18  Sat   Away
# 19  2024-12-07  12:30 (13:30)  Championship         Matchweek 19  Sat   Home
# 20  2024-12-10  20:00 (21:00)  Championship         Matchweek 20  Tue   Home
# 21  2024-12-14  12:30 (13:30)  Championship         Matchweek 21  Sat   Away
# 22  2024-12-21  15:00 (16:00)  Championship         Matchweek 22  Sat   Home
# 23  2024-12-26  20:00 (21:00)  Championship         Matchweek 23  Thu   Away
# 24  2024-12-29  17:45 (18:45)  Championship         Matchweek 24  Sun   Away
# 25  2025-01-01  15:00 (16:00)  Championship         Matchweek 25  Wed   Home
# 26  2025-01-04  15:00 (16:00)  Championship         Matchweek 26  Sat   Away
# 27  2025-01-11  17:45 (18:45)        FA Cup   Third round proper  Sat   Home
# 20  Pascal Struijk    4-2-3-1        4-2-3-1          Ben Toner  Match Report
# 21  Pascal Struijk    4-2-3-1        4-2-3-1         John Busby  Match Report
# 22    Ethan Ampadu    4-2-3-1          4-5-1         James Bell  Match Report
# 23    Ethan Ampadu    4-2-3-1          5-4-1     Stephen Martin  Match Report
# 24    Ethan Ampadu    4-2-3-1        4-2-3-1      Andrew Davies  Match Report
# 25  Pascal Struijk    4-2-3-1        4-2-3-1    Oliver Langford  Match Report
# 26    Ethan Ampadu    4-2-3-1        4-2-3-1  Anthony Backhouse  Match Report
# 27    Ethan Ampadu    4-2-3-1          4-4-2         James Bell  Match Report
# 28    Ethan Ampadu    4-2-3-1        4-2-3-1         David Webb  Match Report
# 29    Ethan Ampadu    4-2-3-1          4-3-3       Matt Donohue  Match Report
# 30         Captain  Formation  Opp Formation            Referee  Match Report
# 31    Ethan Ampadu    4-2-3-1          4-4-2       Joshua Smith  Match Report
# 32    Ethan Ampadu    4-2-3-1        4-2-3-1  Michael Salisbury  Match Report
# 33    Ethan Ampadu    4-2-3-1          3-5-2    Dean Whitestone  Match Report
# 34    Ethan Ampadu    4-2-3-1        4-2-3-1         Gavin Ward  Match Report
# 35    Ethan Ampadu    4-2-3-1        4-2-3-1    Oliver Langford  Match Report
# 36    Ethan Ampadu    4-2-3-1        4-2-3-1     Stuart Attwell  Match Report
# 37  Pascal Struijk    4-2-3-1        4-2-3-1         David Webb  Match Report
# 38  Pascal Struijk    4-2-3-1        4-2-3-1       Farai Hallam  Match Report
# 39  Pascal Struijk    4-2-3-1        4-2-3-1       Robert Jones  Match Report
# 40  Pascal Struijk    4-2-3-1        4-2-3-1    Dean Whitestone  Match Report
# 41  Pascal Struijk    4-2-3-1        4-2-3-1       Tim Robinson  Match Report
# 42    Ethan Ampadu    4-2-3-1          4-4-2          Ben Toner  Match Report
# 43    Ethan Ampadu    4-2-3-1          3-5-2     Thomas Bramall  Match Report
# 44    Ethan Ampadu    4-2-3-1        4-4-1-1     Andrew Kitchen  Match Report
# 45             NaN        NaN            NaN                NaN  Head-to-Head
# 46             NaN        NaN            NaN                NaN  Head-to-Head
# 47             NaN        NaN            NaN                NaN  Head-to-Head
# 48             NaN        NaN            NaN                NaN  Head-to-Head
# 49             NaN        NaN            NaN                NaN  Head-to-Head
#
#     Notes
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30  Notes
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN

# %%
soup = BeautifulSoup(data)
links = soup.find_all('a', href=True)
links = [l.get("href") for l in links] # extract the 'href' attribute from each anchor tag
links = [l for l in links if l and 'all_comps/shooting/' in l] # Filter links to only those linked to the shooting stats page (and are not None)

# %%
driver.get(f"https://fbref.com{links[0]}")
data = StringIO(driver.page_source)

# %%
shooting = pd.read_html(data, match="Shooting", flavor='html5lib')[0]

# %%
shooting.head(5)
# Out:
#   For Leeds United                                                       \
#               Date           Time          Comp        Round  Day Venue
# 0       2024-08-10  12:30 (13:30)  Championship  Matchweek 1  Sat  Home
# 1       2024-08-14  20:00 (21:00)       EFL Cup  First round  Wed  Home
# 2       2024-08-17  12:30 (13:30)  Championship  Matchweek 2  Sat  Away
# 3       2024-08-23  20:00 (21:00)  Championship  Matchweek 3  Fri  Away
# 4       2024-08-31  15:00 (16:00)  Championship  Matchweek 4  Sat  Home
#
#                                 ... Standard               Expected       \
#   Result GF GA        Opponent  ...     Dist   FK PK PKatt       xG npxG
# 0      D  3  3      Portsmouth  ...     16.6    1  1     1      3.3  2.5
# 1      L  0  3   Middlesbrough  ...      NaN  NaN  0     0      NaN  NaN
# 2      D  0  0       West Brom  ...     20.3    0  0     0      0.7  0.7
# 3      W  2  0  Sheffield Weds  ...     18.4    1  0     0      1.2  1.2
# 4      W  2  0       Hull City  ...     17.6    1  0     0      1.5  1.5
#
#                         Unnamed: 25_level_0
#   npxG/Sh  G-xG np:G-xG        Match Report
# 0    0.13  -0.3    -0.5        Match Report
# 1     NaN   NaN     NaN        Match Report
# 2    0.09  -0.7    -0.7        Match Report
# 3    0.09  +0.8    +0.8        Match Report
# 4    0.09  +0.5    +0.5        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel() # remove top of double index heading

# %%
# Merge matches dataframe with some columns of the shooting dataframe using date
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt", "xG", "npxG"]], on="Date")
# Sh = shots, SoT = shots on target, Dist = avg. shot distance, FK = freekicks, PK = penalty kicks, PKatt = penalty kicks attempted, 
# xG = expected goals, npxG = expected goals not including penalties

# %%
team_data.head()
# Out:
#          Date           Time          Comp        Round  Day Venue Result GF  \
# 0  2024-08-10  12:30 (13:30)  Championship  Matchweek 1  Sat  Home      D  3
# 1  2024-08-14  20:00 (21:00)       EFL Cup  First round  Wed  Home      L  0
# 2  2024-08-17  12:30 (13:30)  Championship  Matchweek 2  Sat  Away      D  0
# 3  2024-08-23  20:00 (21:00)  Championship  Matchweek 3  Fri  Away      W  2
# 4  2024-08-31  15:00 (16:00)  Championship  Matchweek 4  Sat  Home      W  2
#
#   GA        Opponent  ...  Match Report Notes  Sh SoT  Dist   FK PK PKatt  \
# 0  3      Portsmouth  ...  Match Report   NaN  21   9  16.6    1  1     1
# 1  3   Middlesbrough  ...  Match Report   NaN  12   2   NaN  NaN  0     0
# 2  0       West Brom  ...  Match Report   NaN   8   1  20.3    0  0     0
# 3  0  Sheffield Weds  ...  Match Report   NaN  13   5  18.4    1  0     0
# 4  0       Hull City  ...  Match Report   NaN  16   5  17.6    1  0     0
#
#   xG_y npxG
# 0  3.3  2.5
# 1  NaN  NaN
# 2  0.7  0.7
# 3  1.2  1.2
# 4  1.5  1.5
#
# [5 rows x 28 columns]

# %%
# Begin process of scraping data from multiple teams for multiple years using a for loop

years = list(range(2025, 2022, -1))
all_matches = []

# %%
import time

league_url = "https://fbref.com/en/comps/10/Championship-Stats"

for year in years:
    driver.get(league_url)
    data = driver.page_source
    soup = BeautifulSoup(data)
    league_table = soup.select_one('table.stats_table')

    links = [l.get("href") for l in league_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]

    previous_season = soup.select_one("a.prev").get("href")
    league_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        driver.get(team_url)
        data = StringIO(driver.page_source)
        matches = pd.read_html(data, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        
        driver.get(f"https://fbref.com{links[0]}")
        data = StringIO(driver.page_source)
        shooting = pd.read_html(data, match="Shooting", flavor='html5lib')[0]
        shooting.columns = shooting.columns.droplevel()

        desired_cols = ["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt", "xG", "npxG"] # FK column has been dropped this season but available for previous
        available_cols = [col for col in desired_cols if col in shooting.columns]
        
        try:
            team_data = matches.merge(shooting[available_cols], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Championship"] # filter out cup games

        team_data["Team"] = team_name
        team_data["Season"] = year
        all_matches.append(team_data) # add team name and season to the list
        time.sleep(3)

# %%
len(all_matches)
# Out:
# 72

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date           time          comp         round  day venue result  \
# 0   2024-08-10  12:30 (13:30)  Championship   Matchweek 1  Sat  Home      D
# 2   2024-08-17  12:30 (13:30)  Championship   Matchweek 2  Sat  Away      D
# 3   2024-08-23  20:00 (21:00)  Championship   Matchweek 3  Fri  Away      W
# 4   2024-08-31  15:00 (16:00)  Championship   Matchweek 4  Sat  Home      W
# 5   2024-09-14  12:30 (13:30)  Championship   Matchweek 5  Sat  Home      L
# ..         ...            ...           ...           ...  ...   ...    ...
# 45  2023-04-15  15:00 (16:00)  Championship  Matchweek 42  Sat  Away      L
# 46  2023-04-18  19:45 (20:45)  Championship  Matchweek 43  Tue  Away      W
# 47  2023-04-22  15:00 (16:00)  Championship  Matchweek 44  Sat  Home      W
# 48  2023-04-29  15:00 (16:00)  Championship  Matchweek 45  Sat  Away      D
# 49  2023-05-08  15:00 (16:00)  Championship  Matchweek 46  Mon  Home      D
#
#    gf ga        opponent  ...  sh sot  dist fk pk pkatt xg_y npxg  \
# 0   3  3      Portsmouth  ...  21   9  16.6  1  1     1  3.3  2.5
# 2   0  0       West Brom  ...   8   1  20.3  0  0     0  0.7  0.7
# 3   2  0  Sheffield Weds  ...  13   5  18.4  1  0     0  1.2  1.2
# 4   2  0       Hull City  ...  16   5  17.6  1  0     0  1.5  1.5
# 5   0  1         Burnley  ...  17   4  18.4  0  0     0  1.2  1.2
# .. .. ..             ...  ...  ..  ..   ... .. ..   ...  ...  ...
# 45  0  1       Blackpool  ...  13   2  14.8  0  0     0  1.1  1.1
# 46  1  0      Stoke City  ...   7   1  20.5  1  0     0  0.7  0.7
# 47  2  1        Millwall  ...  16   2  15.1  1  0     0  1.8  1.8
# 48  1  1         Reading  ...  11   3  11.7  0  0     0  1.7  1.7
# 49  0  0   Rotherham Utd  ...  10   6  18.7  0  0     0  1.0  1.0
#
#               team season
# 0     Leeds United   2025
# 2     Leeds United   2025
# 3     Leeds United   2025
# 4     Leeds United   2025
# 5     Leeds United   2025
# ..             ...    ...
# 45  Wigan Athletic   2023
# 46  Wigan Athletic   2023
# 47  Wigan Athletic   2023
# 48  Wigan Athletic   2023
# 49  Wigan Athletic   2023
#
# [3212 rows x 30 columns]

# %%
from IPython.display import FileLink

match_df.to_csv("matches.csv")
FileLink("matches.csv")
# Out:
# C:\Users\james\matches.csv

# %%
match_df.shape
# Out:
# (3212, 30)
